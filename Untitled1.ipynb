# %%
import pandas as pd
import numpy as np

# %%
data = pd.read_csv('/Users/snehaljsv/Desktop/idsproject/data.csv')
data
# Out:
#              Timestamp                   Email Address  \
# 0   11/9/2023 12:47:44             snehaljsv@gmail.com
# 1   11/9/2023 12:53:00          ec21b1054@iiitdm.ac.in
# 2   11/9/2023 12:54:30          rakeshvr2334@gmail.com
# 3   11/9/2023 12:54:48          ec21b1025@iiitdm.ac.in
# 4   11/9/2023 12:54:52          ec21b1026@iiitdm.ac.in
# ..                 ...                             ...
# 62  11/9/2023 19:19:34          cs23b1029@iiitdm.ac.in
# 63  11/9/2023 19:56:32             saketramt@gmail.com
# 64  11/9/2023 21:13:16       bhaskartejaoffl@gmail.com
# 65  11/9/2023 21:42:44  charanreddy.avireddy@gmail.com
# 66  11/10/2023 8:58:03            jossaneden@gmail.com
#
#     How satisfied are you with our CGPA?(On a scale of 1 to 5)  \
# 0                                                   3
# 1                                                   3
# 2                                                   1
# 3                                                   2
# ...

# %%
data.duplicated()
# Out:
# 0     False
# 1     False
# 2     False
# 3     False
# 4     False
#       ...
# 62    False
# 63    False
# 64    False
# 65    False
# 66    False
# Length: 67, dtype: bool

# %%
data[data.duplicated()]
# Out:
# Empty DataFrame
# Columns: [Timestamp, Email Address, How satisfied are you with our CGPA?(On a scale of 1 to 5), How many days prior end sem you start preparing?, How stressed are you during exams?(On a scale of 1 to 5), How confident are you before taking test? (On a scale of 1 to 5), Do you pay attention to classes regularly?, Unnamed: 7, CGPA(after sem 3)]
# Index: []

# %%
print("DataFrame Info:")
print(data.info())

# Display basic statistics about the numerical columns
print("\nDescriptive Statistics:")
print(data.describe())

# Display the first few rows of the DataFrame
print("\nFirst 5 Rows:")
print(data.head())

# Count the number of missing values in each column
print("\nMissing Values:")
print(data.isnull().sum())
# Out:
# DataFrame Info:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 67 entries, 0 to 66
# Data columns (total 9 columns):
#  #   Column                                                            Non-Null Count  Dtype
# ---  ------                                                            --------------  -----
#  0   Timestamp                                                         67 non-null     object
#  1   Email Address                                                     67 non-null     object
#  2   How satisfied are you with our CGPA?(On a scale of 1 to 5)        67 non-null     int64
#  3   How many days prior end sem you start preparing?                  67 non-null     int64
#  4   How stressed are you during exams?(On a scale of 1 to 5)          67 non-null     int64
#  5   How confident are you before taking test? (On a scale of 1 to 5)  67 non-null     int64
#  6   Do you pay attention to classes regularly?                        67 non-null     object
# ...

# %%
# Get a list of numerical columns
numerical_columns = data.select_dtypes(include=['float64', 'int64']).columns

# Plot histograms for all numerical columns
for column in numerical_columns:
    plt.figure(figsize=(8, 6))
    data[column].plot(kind='hist', bins=20, title=f'Histogram of {column}')
    plt.xlabel(column)
    plt.ylabel('Frequency')
    plt.show()

# %%
import seaborn as sns
numerical_columns = data.select_dtypes(include=['float64', 'int64']).columns

sns.pairplot(data[numerical_columns])
plt.suptitle("Pair Plot of Numerical Columns", y=1.02)
plt.show()
# Out:
# /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/seaborn/axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)

# %%
# Handling Missing Values
# Drop rows with missing values
data = data.dropna()

# Display basic information about the DataFrame after handling missing values
print("\nDataFrame Info After Handling Missing Values:")
print(data.info())

# Removing Duplicates
# Drop duplicate rows
data = data.drop_duplicates()

# Display basic information about the DataFrame after removing duplicates
print("\nDataFrame Info After Removing Duplicates:")
print(data.info())
# Out:
# DataFrame Info After Handling Missing Values:
# <class 'pandas.core.frame.DataFrame'>
# Index: 20 entries, 2 to 66
# Data columns (total 9 columns):
#  #   Column                                                            Non-Null Count  Dtype
# ---  ------                                                            --------------  -----
#  0   Timestamp                                                         20 non-null     object
#  1   Email Address                                                     20 non-null     object
#  2   How satisfied are you with our CGPA?(On a scale of 1 to 5)        20 non-null     int64
#  3   How many days prior end sem you start preparing?                  20 non-null     int64
#  4   How stressed are you during exams?(On a scale of 1 to 5)          20 non-null     int64
#  5   How confident are you before taking test? (On a scale of 1 to 5)  20 non-null     int64
# ...
